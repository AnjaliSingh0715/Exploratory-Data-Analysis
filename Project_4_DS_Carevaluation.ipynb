# %%
import pandas as pd
import numpy as np
import sklearn

# %%
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
from sklearn import linear_model, preprocessing

# %%
data = pd.read_csv("car.data")
data.head()
# Out:
#   buying  maint door persons lug_boot safety  class
# 0  vhigh  vhigh    2       2    small    low  unacc
# 1  vhigh  vhigh    2       2    small    med  unacc
# 2  vhigh  vhigh    2       2    small   high  unacc
# 3  vhigh  vhigh    2       2      med    low  unacc
# 4  vhigh  vhigh    2       2      med    med  unacc

# %% [markdown]
# ok so in this data we have ton of non numerical values right? so now we have two ways to convert it
# ### 1. get dummies method
# ### 2. preprocessing (convert the inot numerical lists as tim said)
#
# i have tried 1 before so am using 2 this time.

# %%
a = preprocessing.LabelEncoder()
buying = a.fit_transform(list(data["buying"]))
maint = a.fit_transform(list(data["maint"]))
door = a.fit_transform(list(data["door"]))
persons = a.fit_transform(list(data["persons"]))
lug_boot = a.fit_transform(list(data["lug_boot"]))
safety = a.fit_transform(list(data["safety"]))
cls = a.fit_transform(list(data["class"]))

# %%
x = list(zip(buying, maint, door, persons, lug_boot, safety))
y = list(cls)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15)

# %%
[buying, safety]
# Out:
# [array([3, 3, 3, ..., 1, 1, 1], dtype=int64),
#  array([1, 2, 0, ..., 1, 2, 0], dtype=int64)]

# %%
model = KNeighborsClassifier(n_neighbors=9)
#you can take diff values instead of 5 and see how model changes

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
accuracy = model.score(x_test,  y_test)
accuracy
# Out:
# 0.9192307692307692

# %%
predicted = model.predict(x_test)

# %%
names = ["unacc", "acc", "good", "vgood"]
for x in range(len(predicted)):
    print("predicted: ", names[predicted[x]], "Data: ", x_test[x], "Actual: ", names[y_test[x]])
# Out:
# predicted:  unacc Data:  (2, 2, 2, 1, 2, 0) Actual:  unacc
# predicted:  good Data:  (1, 2, 3, 1, 2, 1) Actual:  good
# predicted:  good Data:  (2, 2, 0, 0, 2, 2) Actual:  good
# predicted:  good Data:  (0, 3, 1, 0, 2, 0) Actual:  good
# predicted:  good Data:  (1, 3, 1, 2, 2, 0) Actual:  unacc
# predicted:  good Data:  (1, 2, 3, 0, 1, 1) Actual:  good
# predicted:  good Data:  (0, 2, 1, 1, 2, 1) Actual:  good
# predicted:  good Data:  (3, 0, 3, 0, 1, 0) Actual:  good
# predicted:  good Data:  (3, 1, 1, 1, 0, 1) Actual:  good
# predicted:  good Data:  (0, 3, 1, 2, 1, 0) Actual:  good
# predicted:  good Data:  (1, 0, 0, 0, 1, 2) Actual:  good
# predicted:  good Data:  (0, 3, 0, 1, 2, 1) Actual:  good
# predicted:  unacc Data:  (3, 1, 3, 1, 2, 0) Actual:  unacc
# predicted:  good Data:  (1, 3, 3, 2, 2, 2) Actual:  good
# predicted:  good Data:  (2, 0, 0, 2, 1, 1) Actual:  good
# predicted:  good Data:  (0, 3, 2, 1, 1, 1) Actual:  good
# ...
